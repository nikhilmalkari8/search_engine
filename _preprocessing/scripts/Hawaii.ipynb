# %%
import pandas as pd
reviews_df = pd.read_json("../Data/rawData/review-Hawaii.json", lines = True)
reviews_df
# Out:
#               user_id              name           time  rating  \
# 0        1.145634e+20               M J  1625986477698     2.0
# 1        1.060141e+20                DJ  1623740696466     1.0
# 2        1.061359e+20   Gabriela Porras  1529699397115     5.0
# 3        1.008242e+20      Israel Jones  1582583419814     5.0
# 4        1.099007e+20    Alex Y. Moreno  1527050588314     5.0
# ...               ...               ...            ...     ...
# 3111526  1.165499e+20  Lauren Henninger  1578120354635     5.0
# 3111527  1.071717e+20    Alex Belisario  1539011147499     5.0
# 3111528  1.104234e+20      Andrew Davis  1565152300401     5.0
# 3111529  1.011753e+20          Marshall  1552474937379     4.0
# 3111530  1.039377e+20   Anita Nickerson  1565639831015     5.0
#
#                                                       text  \
# 0        We got two size small dogs. Both had wayyyy to...
# 1        The asian guy working there took forever. Almo...
# 2        I have never been a huge fan of hot dogs but t...
# 3        Quality hot dog, delicious toppings!\n\nThe Co...
# 4        I got the Common Kings Dog. It was so much foo...
# ...                                                    ...
# 3111526                                               None
# 3111527                                               None
# 3111528                                               None
# 3111529                                               None
# 3111530                                               None
#
#                                                       pics  resp  \
# 0                                                     None  None
# 1                                                     None  None
# 2        [{'url': ['https://lh5.googleusercontent.com/p...  None
# 3        [{'url': ['https://lh5.googleusercontent.com/p...  None
# 4        [{'url': ['https://lh5.googleusercontent.com/p...  None
# ...                                                    ...   ...
# 3111526                                               None  None
# 3111527                                               None  None
# 3111528  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 3111529                                               None  None
# 3111530                                               None  None
#
#                                        gmap_id
# 0         0x7c00456eecad3111:0x8217f9600c51f33
# 1         0x7c00456eecad3111:0x8217f9600c51f33
# 2         0x7c00456eecad3111:0x8217f9600c51f33
# 3         0x7c00456eecad3111:0x8217f9600c51f33
# 4         0x7c00456eecad3111:0x8217f9600c51f33
# ...                                        ...
# 3111526  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 3111527  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 3111528  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 3111529  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 3111530  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
#
# [3111531 rows x 8 columns]

# %%
reviews_df['user_id'] = reviews_df['user_id'].astype(object)

# %%
reviews_df.drop_duplicates(subset=['user_id', 'text'], inplace = True)

# %%
reviews_df.drop_duplicates(subset = ['user_id', 'gmap_id'], inplace = True)

# %%
pics_df = reviews_df[~reviews_df['pics'].isna()]
pics_df
# Out:
#                          user_id                name           time  rating  \
# 2        106135943668689715200.0     Gabriela Porras  1529699397115     5.0
# 3        100824151868133015552.0        Israel Jones  1582583419814     5.0
# 4        109900744991405703168.0      Alex Y. Moreno  1527050588314     5.0
# 15       117102398803384647680.0         Hakan Soner  1579757581175     1.0
# 36       108990606532348182528.0        Karina Asher  1622395460182     5.0
# ...                          ...                 ...            ...     ...
# 3111325  103517163583915868160.0             M Shimo  1535471299373     3.0
# 3111327  102198137207464525824.0           Siyao Guo  1511038109396     5.0
# 3111331  114742811907050684416.0           oscar rys  1527061920621     4.0
# 3111374  107087110218689167360.0     William Riggins  1603327599739     5.0
# 3111452  112517167791265988608.0  Chastity Bennicoff  1615330811337     5.0
#
#                                                       text  \
# 2        I have never been a huge fan of hot dogs but t...
# 3        Quality hot dog, delicious toppings!\n\nThe Co...
# 4        I got the Common Kings Dog. It was so much foo...
# 15       (Translated by Google) The children's hot dog ...
# 36       You could miss it if you blink, but that’s wha...
# ...                                                    ...
# 3111325  (Translated by Google) It's a license plate wa...
# 3111327  (Translated by Google) A small and fine attrac...
# 3111331  (Translated by Google) 2 min stop but if you a...
# 3111374                                               None
# 3111452                                               None
#
#                                                       pics  resp  \
# 2        [{'url': ['https://lh5.googleusercontent.com/p...  None
# 3        [{'url': ['https://lh5.googleusercontent.com/p...  None
# 4        [{'url': ['https://lh5.googleusercontent.com/p...  None
# 15       [{'url': ['https://lh5.googleusercontent.com/p...  None
# 36       [{'url': ['https://lh5.googleusercontent.com/p...  None
# ...                                                    ...   ...
# 3111325  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 3111327  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 3111331  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 3111374  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 3111452  [{'url': ['https://lh5.googleusercontent.com/p...  None
#
#                                        gmap_id
# 2         0x7c00456eecad3111:0x8217f9600c51f33
# 3         0x7c00456eecad3111:0x8217f9600c51f33
# 4         0x7c00456eecad3111:0x8217f9600c51f33
# 15        0x7c00456eecad3111:0x8217f9600c51f33
# 36       0x7954d376a8b12db3:0xa51dd57e1cc14ca9
# ...                                        ...
# 3111325  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 3111327  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 3111331  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 3111374  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 3111452  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
#
# [229705 rows x 8 columns]

# %%
business_df = pd.read_json("../Data/rawData/meta-Hawaii.json", lines = True, encoding="utf-8")
business_df
# Out:
#                               name  \
# 0                        Hale Pops
# 1      SMP - Single Marine Program
# 2                    2 Cheesy Guys
# 3            Kraken Coffee Kahului
# 4            Akasatana Ramen Kyoto
# ...                            ...
# 21502                   McDonald's
# 21503                     Best Buy
# 21504        Pineapples Restaurant
# 21505              Avis Car Rental
# 21506                Rainbow Falls
#
#                                                  address  \
# 0       Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 1      SMP - Single Marine Program, G St, Kailua, HI ...
# 2           2 Cheesy Guys, 1486 HI-30, Wailuku, HI 96793
# 3      Kraken Coffee Kahului, 520 Keolani Pl, Kahului...
# 4      Akasatana Ramen Kyoto, 1450 Ala Moana Blvd, Ho...
# ...                                                  ...
# 21502  McDonald's, 65-1154 Mamalahoa Hwy, Waimea, HI ...
# 21503    Best Buy, 98-051 Kamehameha Hwy, Aiea, HI 96701
# 21504  Pineapples Restaurant, 332 Keawe St, Hilo, HI ...
# 21505  Avis Car Rental, 300 Rodgers Boulevard Honolul...
# 21506                      Rainbow Falls, Hilo, HI 96720
#
#                                      gmap_id  \
# 0       0x7c00456eecad3111:0x8217f9600c51f33
# 1      0x7c00159b5b1b1d25:0x8d2d85d4a758290e
# 2      0x7954d376a8b12db3:0xa51dd57e1cc14ca9
# 3      0x7954d370921ff6bd:0x3193ba783e26d032
# 4      0x7c006df045b01715:0xe945c308688e1a46
# ...                                      ...
# 21502  0x7953832d482da511:0x7ee6a739b2f11be5
# 21503  0x7c006f55052ca5ab:0x5aab477977480cf6
# 21504  0x79524b579dee4ba5:0xcb4105c1d798a584
# 21505  0x7c006fa13aafa855:0x870a7de67429349c
# 21506  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
#
#                                              description   latitude  \
# 0                                                   None  21.637796
# 1                                                   None  21.440345
# 2                                                   None  20.853014
# 3                                                   None  20.888238
# 4                                                   None  21.290463
# ...                                                  ...        ...
# 21502  Classic, long-running fast-food chain known fo...  20.022391
# 21503  Chain retailer with a large array of brand-nam...  21.384522
# 21504  Happening restaurant featuring New American di...  19.722764
# 21505                                               None  21.333230
# 21506  Rainforest waterfall featuring distinctive rai...  19.719284
#
#         longitude                                           category  \
# 0     -157.920714                                       [Restaurant]
# 1     -157.754347                                [Recreation center]
# 2     -156.503671                                       [Food court]
# 3     -156.450614                                      [Coffee shop]
# 4     -157.843730                                 [Ramen restaurant]
# ...           ...                                                ...
# 21502 -155.666890  [Fast food restaurant, Breakfast restaurant, C...
# 21503 -157.949660  [Electronics store, Appliance store, Computer ...
# 21504 -155.086124  [New American restaurant, American restaurant,...
# 21505 -157.916200                                [Car rental agency]
# 21506 -155.109422                                        [Waterfall]
#
#        avg_rating  num_of_reviews price  \
# 0             4.4              18  None
# 1             4.1              18  None
# 2             5.0               6  None
# 3             4.8               8     $
# 4             5.0               1  None
# ...           ...             ...   ...
# 21502         3.7             338     $
# 21503         4.1            2388    $$
# 21504         4.5            2400    $$
# 21505         3.5             585  None
# 21506         4.6             568  None
#
#                                                    hours  \
# 0      [[Thursday, 11AM–8PM], [Friday, 11AM–8PM], [Sa...
# 1      [[Thursday, 8AM–9PM], [Friday, 8AM–9PM], [Satu...
# 2      [[Thursday, Closed], [Friday, 11AM–6PM], [Satu...
# 3      [[Thursday, 6:30AM–7PM], [Friday, 6:30AM–7PM],...
# 4      [[Thursday, 11AM–8:30PM], [Friday, 11AM–8:30PM...
# ...                                                  ...
# 21502  [[Wednesday, 6AM–9PM], [Thursday, 6AM–9PM], [F...
# 21503  [[Wednesday, 10AM–8PM], [Thursday, 10AM–8PM], ...
# 21504  [[Wednesday, 11AM–9PM], [Thursday, 11AM–9PM], ...
# 21505  [[Wednesday, 4AM–11PM], [Thursday, 4AM–11PM], ...
# 21506                                               None
#
#                                                     MISC  \
# 0      {'Service options': ['Outdoor seating', 'Takeo...
# 1      {'Accessibility': ['Wheelchair accessible entr...
# 2      {'Service options': ['Curbside pickup', 'Takeo...
# 3      {'Service options': ['Curbside pickup', 'No-co...
# 4      {'Service options': ['Takeout', 'Dine-in', 'De...
# ...                                                  ...
# 21502  {'Service options': ['Curbside pickup', 'Drive...
# 21503  {'Service options': ['Curbside pickup', 'In-st...
# 21504  {'Service options': ['Outdoor seating', 'Curbs...
# 21505  {'Highlights': ['Active military discounts'], ...
# 21506                                               None
#
#                          state  \
# 0          Closed ⋅ Opens 11AM
# 1             Opens soon ⋅ 8AM
# 2      Closed ⋅ Opens 11AM Fri
# 3            Open ⋅ Closes 7PM
# 4          Closed ⋅ Opens 11AM
# ...                        ...
# 21502                      NaN
# 21503                      NaN
# 21504                      NaN
# 21505                      NaN
# 21506                      NaN
#
#                                         relative_results  \
# 0      [0x7c00451360f80cf1:0x930291a38bab3132, 0x7c00...
# 1      [0x7c00155df23846af:0xfbe051d208292028, 0x7c00...
# 2                                                   None
# 3                                                   None
# 4      [0x7c006df018f6177d:0x9beb6db40fadcb2, 0x7c006...
# ...                                                  ...
# 21502  [0x79538332de5885b5:0x58215018756b4701, 0x7953...
# 21503  [0x7c00660d84ab0d0b:0xb5564c6a195a009e, 0x7c00...
# 21504  [0x79524ca9dc8eb6a1:0xa8efd269d2d342da, 0x7952...
# 21505  [0x7c006fa7bcf9d287:0x3ed60b5d717e7d7c, 0x7c00...
# 21506                                               None
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 21502  https://www.google.com/maps/place//data=!4m2!3...
# 21503  https://www.google.com/maps/place//data=!4m2!3...
# 21504  https://www.google.com/maps/place//data=!4m2!3...
# 21505  https://www.google.com/maps/place//data=!4m2!3...
# 21506  https://www.google.com/maps/place/Hilo,+HI+967...
#
# [21507 rows x 15 columns]

# %%
business_df.drop_duplicates(subset=['gmap_id'], inplace=True)

# %%
all_df = business_df.merge(pics_df, how = "left", on = ["gmap_id"])
all_df
# Out:
#                              name_x  \
# 0                         Hale Pops
# 1                         Hale Pops
# 2                         Hale Pops
# 3                         Hale Pops
# 4       SMP - Single Marine Program
# ...                             ...
# 237701                Rainbow Falls
# 237702                Rainbow Falls
# 237703                Rainbow Falls
# 237704                Rainbow Falls
# 237705                Rainbow Falls
#
#                                                   address  \
# 0        Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 1        Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 2        Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 3        Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 4       SMP - Single Marine Program, G St, Kailua, HI ...
# ...                                                   ...
# 237701                      Rainbow Falls, Hilo, HI 96720
# 237702                      Rainbow Falls, Hilo, HI 96720
# 237703                      Rainbow Falls, Hilo, HI 96720
# 237704                      Rainbow Falls, Hilo, HI 96720
# 237705                      Rainbow Falls, Hilo, HI 96720
#
#                                       gmap_id  \
# 0        0x7c00456eecad3111:0x8217f9600c51f33
# 1        0x7c00456eecad3111:0x8217f9600c51f33
# 2        0x7c00456eecad3111:0x8217f9600c51f33
# 3        0x7c00456eecad3111:0x8217f9600c51f33
# 4       0x7c00159b5b1b1d25:0x8d2d85d4a758290e
# ...                                       ...
# 237701  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 237702  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 237703  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 237704  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 237705  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
#
#                                               description   latitude  \
# 0                                                    None  21.637796
# 1                                                    None  21.637796
# 2                                                    None  21.637796
# 3                                                    None  21.637796
# 4                                                    None  21.440345
# ...                                                   ...        ...
# 237701  Rainforest waterfall featuring distinctive rai...  19.719284
# 237702  Rainforest waterfall featuring distinctive rai...  19.719284
# 237703  Rainforest waterfall featuring distinctive rai...  19.719284
# 237704  Rainforest waterfall featuring distinctive rai...  19.719284
# 237705  Rainforest waterfall featuring distinctive rai...  19.719284
#
#          longitude             category  avg_rating  num_of_reviews price  \
# 0      -157.920714         [Restaurant]         4.4              18  None
# 1      -157.920714         [Restaurant]         4.4              18  None
# 2      -157.920714         [Restaurant]         4.4              18  None
# 3      -157.920714         [Restaurant]         4.4              18  None
# 4      -157.754347  [Recreation center]         4.1              18  None
# ...            ...                  ...         ...             ...   ...
# 237701 -155.109422          [Waterfall]         4.6             568  None
# 237702 -155.109422          [Waterfall]         4.6             568  None
# 237703 -155.109422          [Waterfall]         4.6             568  None
# 237704 -155.109422          [Waterfall]         4.6             568  None
# 237705 -155.109422          [Waterfall]         4.6             568  None
#
#         ...                state  \
# 0       ...  Closed ⋅ Opens 11AM
# 1       ...  Closed ⋅ Opens 11AM
# 2       ...  Closed ⋅ Opens 11AM
# 3       ...  Closed ⋅ Opens 11AM
# 4       ...     Opens soon ⋅ 8AM
# ...     ...                  ...
# 237701  ...                  NaN
# 237702  ...                  NaN
# 237703  ...                  NaN
# 237704  ...                  NaN
# 237705  ...                  NaN
#
#                                          relative_results  \
# 0       [0x7c00451360f80cf1:0x930291a38bab3132, 0x7c00...
# 1       [0x7c00451360f80cf1:0x930291a38bab3132, 0x7c00...
# 2       [0x7c00451360f80cf1:0x930291a38bab3132, 0x7c00...
# 3       [0x7c00451360f80cf1:0x930291a38bab3132, 0x7c00...
# 4       [0x7c00155df23846af:0xfbe051d208292028, 0x7c00...
# ...                                                   ...
# 237701                                               None
# 237702                                               None
# 237703                                               None
# 237704                                               None
# 237705                                               None
#
#                                                       url  \
# 0       https://www.google.com/maps/place//data=!4m2!3...
# 1       https://www.google.com/maps/place//data=!4m2!3...
# 2       https://www.google.com/maps/place//data=!4m2!3...
# 3       https://www.google.com/maps/place//data=!4m2!3...
# 4       https://www.google.com/maps/place//data=!4m2!3...
# ...                                                   ...
# 237701  https://www.google.com/maps/place/Hilo,+HI+967...
# 237702  https://www.google.com/maps/place/Hilo,+HI+967...
# 237703  https://www.google.com/maps/place/Hilo,+HI+967...
# 237704  https://www.google.com/maps/place/Hilo,+HI+967...
# 237705  https://www.google.com/maps/place/Hilo,+HI+967...
#
#                         user_id              name_y          time rating  \
# 0       106135943668689715200.0     Gabriela Porras  1.529699e+12    5.0
# 1       100824151868133015552.0        Israel Jones  1.582583e+12    5.0
# 2       109900744991405703168.0      Alex Y. Moreno  1.527051e+12    5.0
# 3       117102398803384647680.0         Hakan Soner  1.579758e+12    1.0
# 4                           NaN                 NaN           NaN    NaN
# ...                         ...                 ...           ...    ...
# 237701  103517163583915868160.0             M Shimo  1.535471e+12    3.0
# 237702  102198137207464525824.0           Siyao Guo  1.511038e+12    5.0
# 237703  114742811907050684416.0           oscar rys  1.527062e+12    4.0
# 237704  107087110218689167360.0     William Riggins  1.603328e+12    5.0
# 237705  112517167791265988608.0  Chastity Bennicoff  1.615331e+12    5.0
#
#                                                      text  \
# 0       I have never been a huge fan of hot dogs but t...
# 1       Quality hot dog, delicious toppings!\n\nThe Co...
# 2       I got the Common Kings Dog. It was so much foo...
# 3       (Translated by Google) The children's hot dog ...
# 4                                                     NaN
# ...                                                   ...
# 237701  (Translated by Google) It's a license plate wa...
# 237702  (Translated by Google) A small and fine attrac...
# 237703  (Translated by Google) 2 min stop but if you a...
# 237704                                               None
# 237705                                               None
#
#                                                      pics  resp
# 0       [{'url': ['https://lh5.googleusercontent.com/p...  None
# 1       [{'url': ['https://lh5.googleusercontent.com/p...  None
# 2       [{'url': ['https://lh5.googleusercontent.com/p...  None
# 3       [{'url': ['https://lh5.googleusercontent.com/p...  None
# 4                                                     NaN   NaN
# ...                                                   ...   ...
# 237701  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 237702  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 237703  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 237704  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 237705  [{'url': ['https://lh5.googleusercontent.com/p...  None
#
# [237706 rows x 22 columns]

# %%
all_df.drop(columns=['resp', 'relative_results', 'state'], inplace=True)

# %%
all_df.rename(columns = {'name_x': 'business_name', 'name_y': 'user_name', 'gmap_id': 'business_id'}, inplace = True)

# %%
final_df = all_df[~all_df['user_id'].isna()].copy()
final_df
# Out:
#         business_name                                           address  \
# 0           Hale Pops  Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 1           Hale Pops  Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 2           Hale Pops  Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 3           Hale Pops  Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
# 5       2 Cheesy Guys      2 Cheesy Guys, 1486 HI-30, Wailuku, HI 96793
# ...               ...                                               ...
# 237701  Rainbow Falls                     Rainbow Falls, Hilo, HI 96720
# 237702  Rainbow Falls                     Rainbow Falls, Hilo, HI 96720
# 237703  Rainbow Falls                     Rainbow Falls, Hilo, HI 96720
# 237704  Rainbow Falls                     Rainbow Falls, Hilo, HI 96720
# 237705  Rainbow Falls                     Rainbow Falls, Hilo, HI 96720
#
#                                   business_id  \
# 0        0x7c00456eecad3111:0x8217f9600c51f33
# 1        0x7c00456eecad3111:0x8217f9600c51f33
# 2        0x7c00456eecad3111:0x8217f9600c51f33
# 3        0x7c00456eecad3111:0x8217f9600c51f33
# 5       0x7954d376a8b12db3:0xa51dd57e1cc14ca9
# ...                                       ...
# 237701  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 237702  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 237703  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 237704  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
# 237705  0x7953b4a4114e37f7:0x374b5a1f84f48a1a
#
#                                               description   latitude  \
# 0                                                    None  21.637796
# 1                                                    None  21.637796
# 2                                                    None  21.637796
# 3                                                    None  21.637796
# 5                                                    None  20.853014
# ...                                                   ...        ...
# 237701  Rainforest waterfall featuring distinctive rai...  19.719284
# 237702  Rainforest waterfall featuring distinctive rai...  19.719284
# 237703  Rainforest waterfall featuring distinctive rai...  19.719284
# 237704  Rainforest waterfall featuring distinctive rai...  19.719284
# 237705  Rainforest waterfall featuring distinctive rai...  19.719284
#
#          longitude      category  avg_rating  num_of_reviews price  \
# 0      -157.920714  [Restaurant]         4.4              18  None
# 1      -157.920714  [Restaurant]         4.4              18  None
# 2      -157.920714  [Restaurant]         4.4              18  None
# 3      -157.920714  [Restaurant]         4.4              18  None
# 5      -156.503671  [Food court]         5.0               6  None
# ...            ...           ...         ...             ...   ...
# 237701 -155.109422   [Waterfall]         4.6             568  None
# 237702 -155.109422   [Waterfall]         4.6             568  None
# 237703 -155.109422   [Waterfall]         4.6             568  None
# 237704 -155.109422   [Waterfall]         4.6             568  None
# 237705 -155.109422   [Waterfall]         4.6             568  None
#
#                                                     hours  \
# 0       [[Thursday, 11AM–8PM], [Friday, 11AM–8PM], [Sa...
# 1       [[Thursday, 11AM–8PM], [Friday, 11AM–8PM], [Sa...
# 2       [[Thursday, 11AM–8PM], [Friday, 11AM–8PM], [Sa...
# 3       [[Thursday, 11AM–8PM], [Friday, 11AM–8PM], [Sa...
# 5       [[Thursday, Closed], [Friday, 11AM–6PM], [Satu...
# ...                                                   ...
# 237701                                               None
# 237702                                               None
# 237703                                               None
# 237704                                               None
# 237705                                               None
#
#                                                      MISC  \
# 0       {'Service options': ['Outdoor seating', 'Takeo...
# 1       {'Service options': ['Outdoor seating', 'Takeo...
# 2       {'Service options': ['Outdoor seating', 'Takeo...
# 3       {'Service options': ['Outdoor seating', 'Takeo...
# 5       {'Service options': ['Curbside pickup', 'Takeo...
# ...                                                   ...
# 237701                                               None
# 237702                                               None
# 237703                                               None
# 237704                                               None
# 237705                                               None
#
#                                                       url  \
# 0       https://www.google.com/maps/place//data=!4m2!3...
# 1       https://www.google.com/maps/place//data=!4m2!3...
# 2       https://www.google.com/maps/place//data=!4m2!3...
# 3       https://www.google.com/maps/place//data=!4m2!3...
# 5       https://www.google.com/maps/place//data=!4m2!3...
# ...                                                   ...
# 237701  https://www.google.com/maps/place/Hilo,+HI+967...
# 237702  https://www.google.com/maps/place/Hilo,+HI+967...
# 237703  https://www.google.com/maps/place/Hilo,+HI+967...
# 237704  https://www.google.com/maps/place/Hilo,+HI+967...
# 237705  https://www.google.com/maps/place/Hilo,+HI+967...
#
#                         user_id           user_name          time  rating  \
# 0       106135943668689715200.0     Gabriela Porras  1.529699e+12     5.0
# 1       100824151868133015552.0        Israel Jones  1.582583e+12     5.0
# 2       109900744991405703168.0      Alex Y. Moreno  1.527051e+12     5.0
# 3       117102398803384647680.0         Hakan Soner  1.579758e+12     1.0
# 5       108990606532348182528.0        Karina Asher  1.622395e+12     5.0
# ...                         ...                 ...           ...     ...
# 237701  103517163583915868160.0             M Shimo  1.535471e+12     3.0
# 237702  102198137207464525824.0           Siyao Guo  1.511038e+12     5.0
# 237703  114742811907050684416.0           oscar rys  1.527062e+12     4.0
# 237704  107087110218689167360.0     William Riggins  1.603328e+12     5.0
# 237705  112517167791265988608.0  Chastity Bennicoff  1.615331e+12     5.0
#
#                                                      text  \
# 0       I have never been a huge fan of hot dogs but t...
# 1       Quality hot dog, delicious toppings!\n\nThe Co...
# 2       I got the Common Kings Dog. It was so much foo...
# 3       (Translated by Google) The children's hot dog ...
# 5       You could miss it if you blink, but that’s wha...
# ...                                                   ...
# 237701  (Translated by Google) It's a license plate wa...
# 237702  (Translated by Google) A small and fine attrac...
# 237703  (Translated by Google) 2 min stop but if you a...
# 237704                                               None
# 237705                                               None
#
#                                                      pics
# 0       [{'url': ['https://lh5.googleusercontent.com/p...
# 1       [{'url': ['https://lh5.googleusercontent.com/p...
# 2       [{'url': ['https://lh5.googleusercontent.com/p...
# 3       [{'url': ['https://lh5.googleusercontent.com/p...
# 5       [{'url': ['https://lh5.googleusercontent.com/p...
# ...                                                   ...
# 237701  [{'url': ['https://lh5.googleusercontent.com/p...
# 237702  [{'url': ['https://lh5.googleusercontent.com/p...
# 237703  [{'url': ['https://lh5.googleusercontent.com/p...
# 237704  [{'url': ['https://lh5.googleusercontent.com/p...
# 237705  [{'url': ['https://lh5.googleusercontent.com/p...
#
# [229705 rows x 19 columns]

# %%
final_df.dtypes
# Out:
# business_name      object
# address            object
# business_id        object
# description        object
# latitude          float64
# longitude         float64
# category           object
# avg_rating        float64
# num_of_reviews      int64
# price              object
# hours              object
# MISC               object
# url                object
# user_id            object
# user_name          object
# time              float64
# rating            float64
# text               object
# pics               object
# dtype: object

# %%
final_df.to_json('../Data/rawData/final_Hawaii.json', orient = 'records', indent = 2)

# %%
import json

f = open('../Data/rawData/final_Hawaii.json')
data = json.load(f)

# %%
grouped_reviews = {}
for review in data:
    business_id = review['business_id']
    if business_id not in grouped_reviews:
        # initialize an empty list to store reviews of a business
        grouped_reviews[business_id] = {
            "business_id": business_id,
            "business_name": review['business_name'],
            "address": review['address'],
            "description": review['description'],
            "latitude": review['latitude'],
            "longitude": review['longitude'],
            "category": review['category'],
            "avg_rating": review['avg_rating'],
            "num_of_reviews": review['num_of_reviews'],
            "price": review['price'],
            "hours": review['hours'],
            "MISC": review['MISC'],
            "url": review['url'],
            "reviews": []
        }
    # append the review to the corresponding business
    grouped_reviews[business_id]['reviews'].append({
        "user_id": review['user_id'],
        "user_name": review['user_name'],
        "time": review['time'],
        "rating": review['rating'],
        "text": review['text'],
        "pics": review['pics']
    })

# %%
with open('../Data/Businesses_final/Hawaii_grouped_businesses.json', 'w') as f:
    json.dump(list(grouped_reviews.values()), f, indent = 2)
